# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={weather_api_key}&units={units}&q="
lat = []
lon = []
temp_max = []
humidity = []
cloud = []
wind = []
dt = []
city_name = []
set_count = 1
record_count = 1
print("Beginning Data Retrieval")
print("-----------------------------------")
for index, city in enumerate(cities):
    if(index % 50 == 0 and index >=50):
        set_count += 1
        record_count = 0
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        city_query = query_url + city
        response = requests.get(city_query).json()

        city_lat = response['coord']['lat']
        city_lon = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_cloud = response['clouds']['all']
        city_wind_speed = response['wind']['speed']
        city_date = response['dt']

        lat.append(city_lat)
        lon.append(city_lon)
        temp_max.append(city_max_temp)
        humidity.append(city_humidity)
        cloud.append(city_cloud)
        wind.append(city_wind_speed)
        dt.append(city_date)
        city_name.append(city)
        
    except:
        print("City not found")
# Out:
# Beginning Data Retrieval
# -----------------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | deshnok
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | la presa
# Processing Record 5 of Set 1 | ballangen
# Processing Record 6 of Set 1 | vestmanna
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | taolanaro
# City not found
# Processing Record 12 of Set 1 | keshorai patan
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | kusa
# Processing Record 15 of Set 1 | vieques
# Processing Record 16 of Set 1 | baie-saint-paul
# Processing Record 17 of Set 1 | asosa
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | san quintin
# Processing Record 20 of Set 1 | manokwari
# Processing Record 21 of Set 1 | carndonagh
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | mys shmidta
# City not found
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | semey
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | jand
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | nishihara
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | vila velha
# Processing Record 33 of Set 1 | port hawkesbury
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | rawson
# Processing Record 36 of Set 1 | paciran
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | staroye drozhzhanoye
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | hirara
# Processing Record 45 of Set 1 | bartica
# Processing Record 46 of Set 1 | antofagasta
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | aykhal
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | chuy
# Processing Record 0 of Set 2 | maceio
# Processing Record 1 of Set 2 | toulepleu
# City not found
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | roald
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | bubaque
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | half moon bay
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | solovetskiy
# City not found
# Processing Record 13 of Set 2 | borogontsy
# Processing Record 14 of Set 2 | umzimvubu
# City not found
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | ushtobe
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | solnechnyy
# Processing Record 20 of Set 2 | loikaw
# Processing Record 21 of Set 2 | orodara
# Processing Record 22 of Set 2 | ozgon
# City not found
# Processing Record 23 of Set 2 | alta floresta
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | mogzon
# Processing Record 28 of Set 2 | axim
# Processing Record 29 of Set 2 | russell
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | jaque
# Processing Record 32 of Set 2 | itarema
# Processing Record 33 of Set 2 | buraydah
# Processing Record 34 of Set 2 | poum
# Processing Record 35 of Set 2 | grand gaube
# Processing Record 36 of Set 2 | vila franca do campo
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | pisco
# Processing Record 41 of Set 2 | sabha
# Processing Record 42 of Set 2 | diffa
# Processing Record 43 of Set 2 | lazi
# Processing Record 44 of Set 2 | salalah
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | shihezi
# Processing Record 48 of Set 2 | havoysund
# Processing Record 49 of Set 2 | scranton
# Processing Record 0 of Set 3 | port elizabeth
# Processing Record 1 of Set 3 | nizhneyansk
# City not found
# Processing Record 2 of Set 3 | ati
# Processing Record 3 of Set 3 | robertson
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | richards bay
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | yeppoon
# Processing Record 8 of Set 3 | svetlogorsk
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | smolenka
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | vaitupu
# City not found
# Processing Record 14 of Set 3 | una
# Processing Record 15 of Set 3 | carlisle
# Processing Record 16 of Set 3 | umm lajj
# Processing Record 17 of Set 3 | tual
# Processing Record 18 of Set 3 | cessnock
# Processing Record 19 of Set 3 | bachatskiy
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | carutapera
# Processing Record 24 of Set 3 | qaqortoq
# Processing Record 25 of Set 3 | saint-augustin
# Processing Record 26 of Set 3 | hamilton
# Processing Record 27 of Set 3 | sorong
# Processing Record 28 of Set 3 | taoudenni
# Processing Record 29 of Set 3 | tiznit
# Processing Record 30 of Set 3 | tiruvottiyur
# City not found
# Processing Record 31 of Set 3 | miyako
# Processing Record 32 of Set 3 | llanes
# Processing Record 33 of Set 3 | ossora
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | joshimath
# Processing Record 37 of Set 3 | lakes entrance
# Processing Record 38 of Set 3 | saint-leu
# Processing Record 39 of Set 3 | koutsouras
# Processing Record 40 of Set 3 | korla
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | impfondo
# Processing Record 43 of Set 3 | kautokeino
# Processing Record 44 of Set 3 | cherskiy
# Processing Record 45 of Set 3 | todos santos
# Processing Record 46 of Set 3 | ngunguru
# Processing Record 47 of Set 3 | lata
# Processing Record 48 of Set 3 | bar harbor
# Processing Record 49 of Set 3 | bath
# Processing Record 0 of Set 4 | isangel
# Processing Record 1 of Set 4 | jorpeland
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | rincon
# Processing Record 4 of Set 4 | hovd
# Processing Record 5 of Set 4 | grand river south east
# City not found
# Processing Record 6 of Set 4 | muzhi
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | lolua
# City not found
# Processing Record 9 of Set 4 | samarai
# Processing Record 10 of Set 4 | attawapiskat
# City not found
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | emerald
# Processing Record 15 of Set 4 | vaini
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | xghajra
# City not found
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | kahului
# Processing Record 20 of Set 4 | bajram curri
# Processing Record 21 of Set 4 | halalo
# City not found
# Processing Record 22 of Set 4 | barrow
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | christchurch
# Processing Record 26 of Set 4 | gongzhuling
# Processing Record 27 of Set 4 | cairns
# Processing Record 28 of Set 4 | kavali
# Processing Record 29 of Set 4 | tsihombe
# City not found
# Processing Record 30 of Set 4 | pochutla
# Processing Record 31 of Set 4 | praia
# Processing Record 32 of Set 4 | okha
# Processing Record 33 of Set 4 | dundee
# Processing Record 34 of Set 4 | champerico
# Processing Record 35 of Set 4 | manavalakurichi
# Processing Record 36 of Set 4 | riachao das neves
# Processing Record 37 of Set 4 | esmeraldas
# Processing Record 38 of Set 4 | broome
# Processing Record 39 of Set 4 | tambacounda
# Processing Record 40 of Set 4 | loviisa
# Processing Record 41 of Set 4 | meulaboh
# Processing Record 42 of Set 4 | port pirie
# Processing Record 43 of Set 4 | komsomolskiy
# Processing Record 44 of Set 4 | ulaangom
# Processing Record 45 of Set 4 | swan hill
# Processing Record 46 of Set 4 | zalantun
# Processing Record 47 of Set 4 | olean
# Processing Record 48 of Set 4 | toba
# Processing Record 49 of Set 4 | kailua
# Processing Record 0 of Set 5 | north bend
# Processing Record 1 of Set 5 | havre-saint-pierre
# Processing Record 2 of Set 5 | serov
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | matagami
# Processing Record 5 of Set 5 | lillooet
# Processing Record 6 of Set 5 | terenos
# Processing Record 7 of Set 5 | mahibadhoo
# Processing Record 8 of Set 5 | belushya guba
# City not found
# Processing Record 9 of Set 5 | vao
# Processing Record 10 of Set 5 | boyolangu
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | ibra
# Processing Record 13 of Set 5 | zhigansk
# Processing Record 14 of Set 5 | east london
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | jaciara
# Processing Record 17 of Set 5 | rolim de moura
# City not found
# Processing Record 18 of Set 5 | paamiut
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | saint anthony
# Processing Record 21 of Set 5 | narsaq
# Processing Record 22 of Set 5 | mendahara
# City not found
# Processing Record 23 of Set 5 | rungata
# City not found
# Processing Record 24 of Set 5 | damghan
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | seymchan
# Processing Record 27 of Set 5 | naftalan
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | zhuhai
# Processing Record 30 of Set 5 | jiangyou
# Processing Record 31 of Set 5 | sayhat
# Processing Record 32 of Set 5 | tumannyy
# City not found
# Processing Record 33 of Set 5 | novara
# Processing Record 34 of Set 5 | sitka
# Processing Record 35 of Set 5 | umarkot
# Processing Record 36 of Set 5 | portland
# Processing Record 37 of Set 5 | gurgan
# City not found
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | bolshegrivskoye
# City not found
# Processing Record 40 of Set 5 | asau
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | kachiry
# Processing Record 43 of Set 5 | barentsburg
# City not found
# Processing Record 44 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 5 | verkh-usugli
# Processing Record 46 of Set 5 | tuktoyaktuk
# Processing Record 47 of Set 5 | artyk
# City not found
# Processing Record 48 of Set 5 | katsuura
# Processing Record 49 of Set 5 | shahrud
# Processing Record 0 of Set 6 | cockburn town
# Processing Record 1 of Set 6 | leningradskiy
# Processing Record 2 of Set 6 | solsvik
# City not found
# Processing Record 3 of Set 6 | zaragoza
# Processing Record 4 of Set 6 | concepcion del oro
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | sedam
# Processing Record 8 of Set 6 | te anau
# Processing Record 9 of Set 6 | wahran
# City not found
# Processing Record 10 of Set 6 | fort nelson
# Processing Record 11 of Set 6 | fare
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | gweru
# Processing Record 14 of Set 6 | muisne
# Processing Record 15 of Set 6 | hambantota
# Processing Record 16 of Set 6 | plouzane
# Processing Record 17 of Set 6 | urucui
# Processing Record 18 of Set 6 | samalaeulu
# City not found
# Processing Record 19 of Set 6 | limon
# Processing Record 20 of Set 6 | soledade
# Processing Record 21 of Set 6 | songkhla
# Processing Record 22 of Set 6 | sinkat
# City not found
# Processing Record 23 of Set 6 | presidencia roque saenz pena
# Processing Record 24 of Set 6 | neepawa
# Processing Record 25 of Set 6 | grand centre
# City not found
# Processing Record 26 of Set 6 | mangai
# Processing Record 27 of Set 6 | aklavik
# Processing Record 28 of Set 6 | hasaki
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | warmbad
# Processing Record 31 of Set 6 | lugoba
# Processing Record 32 of Set 6 | sioux lookout
# Processing Record 33 of Set 6 | mitsamiouli
# Processing Record 34 of Set 6 | fort dix
# Processing Record 35 of Set 6 | xai-xai
# Processing Record 36 of Set 6 | nakusp
# Processing Record 37 of Set 6 | katha
# City not found
# Processing Record 38 of Set 6 | arraial do cabo
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | camopi
# Processing Record 41 of Set 6 | fukuma
# Processing Record 42 of Set 6 | knysna
# Processing Record 43 of Set 6 | kurilsk
# Processing Record 44 of Set 6 | ortega
# Processing Record 45 of Set 6 | rio gallegos
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | shirgaon
# Processing Record 48 of Set 6 | samusu
# City not found
# Processing Record 49 of Set 6 | le vauclin
# Processing Record 0 of Set 7 | kloulklubed
# Processing Record 1 of Set 7 | mayo
# Processing Record 2 of Set 7 | kidodi
# Processing Record 3 of Set 7 | paradwip
# City not found
# Processing Record 4 of Set 7 | hanchuan
# Processing Record 5 of Set 7 | salamiyah
# Processing Record 6 of Set 7 | bentiu
# Processing Record 7 of Set 7 | praya
# Processing Record 8 of Set 7 | pespire
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | langsa
# Processing Record 11 of Set 7 | pevek
# Processing Record 12 of Set 7 | viedma
# Processing Record 13 of Set 7 | gigmoto
# Processing Record 14 of Set 7 | wajima
# Processing Record 15 of Set 7 | pangnirtung
# Processing Record 16 of Set 7 | lagos
# Processing Record 17 of Set 7 | katrineholm
# Processing Record 18 of Set 7 | dhidhdhoo
# Processing Record 19 of Set 7 | faanui
# Processing Record 20 of Set 7 | tommot
# Processing Record 21 of Set 7 | bengkulu
# Processing Record 22 of Set 7 | salinas
# Processing Record 23 of Set 7 | maragogi
# Processing Record 24 of Set 7 | rosetta
# Processing Record 25 of Set 7 | kudahuvadhoo
# Processing Record 26 of Set 7 | flinders
# Processing Record 27 of Set 7 | cherdyn
# Processing Record 28 of Set 7 | hranice
# Processing Record 29 of Set 7 | manono
# Processing Record 30 of Set 7 | darhan
# Processing Record 31 of Set 7 | bima
# Processing Record 32 of Set 7 | plettenberg bay
# Processing Record 33 of Set 7 | shu
# Processing Record 34 of Set 7 | novobirilyussy
# Processing Record 35 of Set 7 | ola
# Processing Record 36 of Set 7 | hit
# Processing Record 37 of Set 7 | bafoulabe
# Processing Record 38 of Set 7 | burica
# City not found
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | saint-joseph
# Processing Record 41 of Set 7 | oranjemund
# Processing Record 42 of Set 7 | meadow lake
# Processing Record 43 of Set 7 | selty
# Processing Record 44 of Set 7 | bambous virieux
# Processing Record 45 of Set 7 | zolotkovo
# Processing Record 46 of Set 7 | ingham
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | zaysan
# Processing Record 49 of Set 7 | sumbe
# Processing Record 0 of Set 8 | japura
# Processing Record 1 of Set 8 | meylan
# Processing Record 2 of Set 8 | oksfjord
# Processing Record 3 of Set 8 | leinefelde
# Processing Record 4 of Set 8 | dargaville
# Processing Record 5 of Set 8 | shetpe
# Processing Record 6 of Set 8 | morogoro
# Processing Record 7 of Set 8 | deputatskiy
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | nyurba
# Processing Record 10 of Set 8 | iberia
# Processing Record 11 of Set 8 | tura
# Processing Record 12 of Set 8 | krasnoselkup
# Processing Record 13 of Set 8 | beringovskiy
# Processing Record 14 of Set 8 | baykit
# Processing Record 15 of Set 8 | gat
# Processing Record 16 of Set 8 | mabopane
# Processing Record 17 of Set 8 | erie
# Processing Record 18 of Set 8 | oga
# Processing Record 19 of Set 8 | ilhabela
# Processing Record 20 of Set 8 | shenzhen
# Processing Record 21 of Set 8 | olga
# Processing Record 22 of Set 8 | tamale
# Processing Record 23 of Set 8 | salvador
# Processing Record 24 of Set 8 | salina
# Processing Record 25 of Set 8 | buqayq
# City not found
# Processing Record 26 of Set 8 | palabuhanratu
# City not found
# Processing Record 27 of Set 8 | seddon
# Processing Record 28 of Set 8 | verkhnyaya inta
# Processing Record 29 of Set 8 | bereda
# Processing Record 30 of Set 8 | klaksvik
# Processing Record 31 of Set 8 | amapa
# Processing Record 32 of Set 8 | qui nhon
# Processing Record 33 of Set 8 | faya
# Processing Record 34 of Set 8 | lazaro cardenas
# Processing Record 35 of Set 8 | northam
# Processing Record 36 of Set 8 | tahoua
# Processing Record 37 of Set 8 | nemuro
# Processing Record 38 of Set 8 | porto belo
# Processing Record 39 of Set 8 | amderma
# City not found
# Processing Record 40 of Set 8 | kamaishi
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | bonthe
# Processing Record 43 of Set 8 | vallenar
# Processing Record 44 of Set 8 | gustavo diaz ordaz
# Processing Record 45 of Set 8 | veseloyarsk
# Processing Record 46 of Set 8 | nguiu
# City not found
# Processing Record 47 of Set 8 | kota kinabalu
# Processing Record 48 of Set 8 | innisfail
# Processing Record 49 of Set 8 | kenai
# Processing Record 0 of Set 9 | sangmelima
# Processing Record 1 of Set 9 | esperance
# Processing Record 2 of Set 9 | khor
# Processing Record 3 of Set 9 | port keats
# Processing Record 4 of Set 9 | barra do garcas
# Processing Record 5 of Set 9 | macaubas
# Processing Record 6 of Set 9 | khovu-aksy
# Processing Record 7 of Set 9 | serebryansk
# Processing Record 8 of Set 9 | victoria
# Processing Record 9 of Set 9 | marcona
# City not found
# Processing Record 10 of Set 9 | susaki
# Processing Record 11 of Set 9 | ngukurr
# City not found
# Processing Record 12 of Set 9 | lagoa
# Processing Record 13 of Set 9 | palmer
# Processing Record 14 of Set 9 | palatka
# Processing Record 15 of Set 9 | sibu
# Processing Record 16 of Set 9 | aginskoye
# Processing Record 17 of Set 9 | aleksandrov gay
# Processing Record 18 of Set 9 | morro bay
# Processing Record 19 of Set 9 | lindsay
# Processing Record 20 of Set 9 | podor
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | marovoay
# Processing Record 23 of Set 9 | mersing
# Processing Record 24 of Set 9 | sahrak
# City not found
# Processing Record 25 of Set 9 | celestun
# Processing Record 26 of Set 9 | vanimo
# Processing Record 27 of Set 9 | sola
# Processing Record 28 of Set 9 | fevralsk
# City not found
# Processing Record 29 of Set 9 | puerto asis
# Processing Record 30 of Set 9 | yankton
# Processing Record 31 of Set 9 | anderson
# Processing Record 32 of Set 9 | laslea
# Processing Record 33 of Set 9 | martil
# Processing Record 34 of Set 9 | togitsu
# Processing Record 35 of Set 9 | la palma
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | labutta
# City not found
# Processing Record 38 of Set 9 | urulga
# City not found
# Processing Record 39 of Set 9 | hadejia
# Processing Record 40 of Set 9 | nizwa
# Processing Record 41 of Set 9 | iskateley
# Processing Record 42 of Set 9 | dolores
# Processing Record 43 of Set 9 | akyab
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | azimur
# City not found
# Processing Record 46 of Set 9 | susuman
# Processing Record 47 of Set 9 | fuxin
# Processing Record 48 of Set 9 | belaya gora
# Processing Record 49 of Set 9 | clarence town
# Processing Record 0 of Set 10 | san andres
# Processing Record 1 of Set 10 | galle
# Processing Record 2 of Set 10 | at-bashi
# Processing Record 3 of Set 10 | karkaralinsk
# City not found
# Processing Record 4 of Set 10 | labuan
# Processing Record 5 of Set 10 | safwah
# City not found
# Processing Record 6 of Set 10 | bermeo
# Processing Record 7 of Set 10 | ukiah
# Processing Record 8 of Set 10 | akdepe
# Processing Record 9 of Set 10 | staryy nadym
# Processing Record 10 of Set 10 | opuwo
# Processing Record 11 of Set 10 | potosi
# Processing Record 12 of Set 10 | tay ninh
# Processing Record 13 of Set 10 | kumo
# Processing Record 14 of Set 10 | wuchang
# Processing Record 15 of Set 10 | providencia
# Processing Record 16 of Set 10 | mehamn
# Processing Record 17 of Set 10 | constitucion
# Processing Record 18 of Set 10 | nhulunbuy
# Processing Record 19 of Set 10 | yarmouth
# Processing Record 20 of Set 10 | kaeo
# Processing Record 21 of Set 10 | dongsheng
# Processing Record 22 of Set 10 | aden
# Processing Record 23 of Set 10 | kikwit
# Processing Record 24 of Set 10 | nouadhibou
# Processing Record 25 of Set 10 | cap malheureux
# Processing Record 26 of Set 10 | kunming
# Processing Record 27 of Set 10 | vernon
# Processing Record 28 of Set 10 | davila
# Processing Record 29 of Set 10 | pedernales
# Processing Record 30 of Set 10 | boditi
# Processing Record 31 of Set 10 | atambua
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | nortelandia
# Processing Record 34 of Set 10 | skjervoy
# Processing Record 35 of Set 10 | ouegoa
# Processing Record 36 of Set 10 | verkhnevilyuysk
# Processing Record 37 of Set 10 | antsirabe
# Processing Record 38 of Set 10 | laguna
# Processing Record 39 of Set 10 | valkla
# Processing Record 40 of Set 10 | oistins
# Processing Record 41 of Set 10 | muros
# Processing Record 42 of Set 10 | fereydun kenar
# Processing Record 43 of Set 10 | clarksdale
# Processing Record 44 of Set 10 | zabid
# Processing Record 45 of Set 10 | porbandar
# Processing Record 46 of Set 10 | quatre cocos
# Processing Record 47 of Set 10 | najran
# Processing Record 48 of Set 10 | gorno-chuyskiy
# City not found
# Processing Record 49 of Set 10 | riverton
# Processing Record 0 of Set 11 | loubomo
# Processing Record 1 of Set 11 | altamira
# Processing Record 2 of Set 11 | souillac
# Processing Record 3 of Set 11 | waipawa
# Processing Record 4 of Set 11 | kamenka
# Processing Record 5 of Set 11 | panjwin
# City not found
# Processing Record 6 of Set 11 | bonavista
# Processing Record 7 of Set 11 | bosaso
# Processing Record 8 of Set 11 | hun
# Processing Record 9 of Set 11 | eyl
# Processing Record 10 of Set 11 | tiarei
# Processing Record 11 of Set 11 | hays
# Processing Record 12 of Set 11 | egvekinot
# Processing Record 13 of Set 11 | aksu
# Processing Record 14 of Set 11 | toliary
# City not found
# Processing Record 15 of Set 11 | mildura
# Processing Record 16 of Set 11 | ratnagiri
# Processing Record 17 of Set 11 | harrison
# Processing Record 18 of Set 11 | rio cuarto
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | kampene
# Processing Record 21 of Set 11 | sao miguel do araguaia
# Processing Record 22 of Set 11 | nalut
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | wenling
# Processing Record 25 of Set 11 | peniche
# Processing Record 26 of Set 11 | arlit
# Processing Record 27 of Set 11 | geraldton
# Processing Record 28 of Set 11 | tevriz
# Processing Record 29 of Set 11 | kakashura
# City not found
# Processing Record 30 of Set 11 | hailun
# Processing Record 31 of Set 11 | kristiansund
# Processing Record 32 of Set 11 | sakaiminato
# Processing Record 33 of Set 11 | nelson bay
# Processing Record 34 of Set 11 | baruun-urt
# Processing Record 35 of Set 11 | sakakah
# Processing Record 36 of Set 11 | temaraia
# City not found
# Processing Record 37 of Set 11 | campos
# Processing Record 38 of Set 11 | concarneau
# Processing Record 39 of Set 11 | tete
# Processing Record 40 of Set 11 | horta
# Processing Record 41 of Set 11 | ancud
# Processing Record 42 of Set 11 | santa marta
# Processing Record 43 of Set 11 | tasbuget
# City not found
# Processing Record 44 of Set 11 | dicabisagan
# Processing Record 45 of Set 11 | luwuk
# Processing Record 46 of Set 11 | changde
# Processing Record 47 of Set 11 | sabang
# Processing Record 48 of Set 11 | port-gentil
# Processing Record 49 of Set 11 | sao raimundo nonato
# Processing Record 0 of Set 12 | ilulissat
# Processing Record 1 of Set 12 | skagastrond
# City not found
# Processing Record 2 of Set 12 | banda aceh
# Processing Record 3 of Set 12 | okato
# Processing Record 4 of Set 12 | kui buri
# Processing Record 5 of Set 12 | fortuna
# Processing Record 6 of Set 12 | chicama
# Processing Record 7 of Set 12 | buchanan
# Processing Record 8 of Set 12 | araouane
# Processing Record 9 of Set 12 | victor harbor
# Processing Record 10 of Set 12 | kashi
# Processing Record 11 of Set 12 | auki
# Processing Record 12 of Set 12 | fort morgan
# Processing Record 13 of Set 12 | neiafu
# Processing Record 14 of Set 12 | pasighat
# Processing Record 15 of Set 12 | maldonado
# Processing Record 16 of Set 12 | tautira
# Processing Record 17 of Set 12 | hauterive
# Processing Record 18 of Set 12 | san carlos
# Processing Record 19 of Set 12 | ketou
# Processing Record 20 of Set 12 | broken hill
# Processing Record 21 of Set 12 | las choapas
# Processing Record 22 of Set 12 | shar
# Processing Record 23 of Set 12 | uhlove
# Processing Record 24 of Set 12 | nome
# Processing Record 25 of Set 12 | evensk
# Processing Record 26 of Set 12 | charters towers
# Processing Record 27 of Set 12 | bambamarca
# Processing Record 28 of Set 12 | guanica
# Processing Record 29 of Set 12 | ellenabad
# Processing Record 30 of Set 12 | diamantina
# Processing Record 31 of Set 12 | ryotsu
# Processing Record 32 of Set 12 | tarazona
# Processing Record 33 of Set 12 | khonuu
# City not found
# Processing Record 34 of Set 12 | cosala
# Processing Record 35 of Set 12 | sao lourenco do sul
# Processing Record 36 of Set 12 | sarangani
# Processing Record 37 of Set 12 | mocambique
# City not found
# Processing Record 38 of Set 12 | daniel flores
# Processing Record 39 of Set 12 | livingston
# Processing Record 40 of Set 12 | mombetsu
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | sotouboua
# Processing Record 43 of Set 12 | pampierstad
# Processing Record 44 of Set 12 | bondo
# Processing Record 45 of Set 12 | paita
# Processing Record 46 of Set 12 | tobe
# Processing Record 47 of Set 12 | aksarka
# Processing Record 48 of Set 12 | anito
# Processing Record 49 of Set 12 | okhotsk
# Processing Record 0 of Set 13 | biloela
# Processing Record 1 of Set 13 | lingyuan
# Processing Record 2 of Set 13 | seoul
# Processing Record 3 of Set 13 | shimoda
# Processing Record 4 of Set 13 | jagtial
# Processing Record 5 of Set 13 | amudat
# Processing Record 6 of Set 13 | kavaratti
# Processing Record 7 of Set 13 | rudnogorsk
# Processing Record 8 of Set 13 | namtsy
# Processing Record 9 of Set 13 | bida
# Processing Record 10 of Set 13 | zaoyang
# Processing Record 11 of Set 13 | kochkurovo
# Processing Record 12 of Set 13 | ixtapa
# Processing Record 13 of Set 13 | takoradi
# Processing Record 14 of Set 13 | luancheng
# Processing Record 15 of Set 13 | guacheta
# Processing Record 16 of Set 13 | kargasok
# Processing Record 17 of Set 13 | oliveira dos brejinhos
# Processing Record 18 of Set 13 | beitbridge
# Processing Record 19 of Set 13 | port macquarie
# Processing Record 20 of Set 13 | galiwinku
# City not found
# Processing Record 21 of Set 13 | chubbuck
# Processing Record 22 of Set 13 | tucuma
# Processing Record 23 of Set 13 | shakawe
# Processing Record 24 of Set 13 | nampula
# Processing Record 25 of Set 13 | ambon

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({"City": city_name, "Lat": lat, "Lng": lon, "Max Temp": temp_max, 
                "Humidity": humidity, "Cloudiness": cloud, "Wind Speed": wind,
                "Date": dt
               })

weather_data.to_csv("cities.csv")
weather_data
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     hermanus -34.42   19.23     16.67        84         100        1.79
# 1      deshnok  27.80   73.34     30.07        17          15        2.95
# 2        tiksi  71.69  128.87     -6.67        98         100        4.34
# 3     la presa  32.71 -117.00     24.44        52           5        1.76
# 4    ballangen  68.34   16.83      3.33        69         100        7.20
# ..         ...    ...     ...       ...       ...         ...         ...
# 563   chubbuck  42.92 -112.47     14.00        44          20       10.30
# 564     tucuma  -0.18  -50.05     32.98        48          89        4.41
# 565    shakawe -18.37   21.85     28.95        15           0        3.04
# 566    nampula -15.12   39.27     28.00        45          20        6.70
# 567      ambon  -3.70  128.18     27.22        93          83        1.96
#
#            Date
# 0    1602953193
# 1    1602953193
# 2    1602953194
# 3    1602953194
# 4    1602953194
# ..          ...
# 563  1602953267
# 564  1602953267
# 565  1602953267
# 566  1602953082
# 567  1602953267
#
# [568 rows x 8 columns]

# %%
weather_data.describe()
# Out:
#               Lat         Lng   Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  568.000000  568.000000  568.00000  568.000000  568.000000  568.000000
# mean    19.371127   22.722553   17.22213   68.700704   48.963028    3.578609
# std     32.804791   91.647464   11.73583   22.148095   37.633717    2.448224
# min    -54.800000 -179.170000  -17.00000    1.000000    0.000000    0.150000
# 25%     -7.247500  -56.990000    9.00000   57.000000    8.000000    1.695000
# 50%     22.180000   25.760000   19.00000   74.000000   45.500000    3.100000
# 75%     45.597500  105.020000   26.23750   85.000000   87.250000    4.660000
# max     78.220000  179.320000   40.00000  100.000000  100.000000   17.230000
#
#                Date
# count  5.680000e+02
# mean   1.602953e+09
# std    6.722360e+01
# min    1.602953e+09
# 25%    1.602953e+09
# 50%    1.602953e+09
# 75%    1.602953e+09
# max    1.602953e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
high_humid = weather_data.loc[(weather_data["Humidity"] > 100)]
high_humid
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Maximum Temperature vs. Latitude")

plt.grid()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Humidity')
plt.title("Humidity vs. Latitude")

plt.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Cloudiness')
plt.title("Cloudiness vs. Latitude")

plt.grid()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Wind Speed')
plt.title("Wind Speed vs. Latitude")

plt.grid()

# %% [markdown]
# ## Linear Regression

# %%
def linreg(x_values, y_values, title, coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_city = weather_data.loc[(weather_data["Lat"] >= 0)]

north_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Maximum Temperature vs. Latitude for Northern Hemisphere")
plt.grid()
x_values = north_city["Lat"]

y_values = north_city["Max Temp"]

linreg(north_city["Lat"],north_city["Max Temp"], "Maximum Temperature", (0,-5))
# Out:
# The r-squared is: -0.8886084205134966

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_city = weather_data.loc[(weather_data["Lat"] < 0)]

south_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Maximum Temperature vs. Latitude for Southern Hemisphere")
plt.grid()
x_values = south_city["Lat"]

y_values = south_city["Max Temp"]

linreg(south_city["Lat"],south_city["Max Temp"], "Maximum Temperature", (-55,35))
# Out:
# The r-squared is: 0.6667730531039028

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Humidity vs. Latitude for Northern Hemisphere")
plt.grid()
x_values = north_city["Lat"]

y_values = north_city["Humidity"]

linreg(north_city["Lat"],north_city["Humidity"], "Humidity", (0,-10))
# Out:
# The r-squared is: 0.2385908831689431

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Humidity vs. Latitude for Southern Hemisphere")
plt.grid()
x_values = south_city["Lat"]

y_values = south_city["Humidity"]

linreg(south_city["Lat"],south_city["Humidity"], "Humidity", (-25,5))
# Out:
# The r-squared is: -0.0841516568813803

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Cloudiness vs. Latitude for Northern Hemisphere")
plt.grid()
x_values = north_city["Lat"]

y_values = north_city["Cloudiness"]

linreg(north_city["Lat"],north_city["Cloudiness"], "Cloudiness", (0,-10))
# Out:
# The r-squared is: 0.2014816417197162

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Cloudiness vs. Latitude for Southern Hemisphere")
plt.grid()
x_values = south_city["Lat"]

y_values = south_city["Cloudiness"]

linreg(south_city["Lat"],south_city["Cloudiness"], "Cloudiness", (-55,50))
# Out:
# The r-squared is: 0.07588281083842631

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Wind Speed vs. Latitude for Northern Hemisphere")
plt.grid()
x_values = north_city["Lat"]

y_values = north_city["Wind Speed"]

linreg(north_city["Lat"],north_city["Wind Speed"], "Wind Speed", (0,-10))
# Out:
# The r-squared is: 0.16245953734819996

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_city.plot(kind='scatter', x='Lat', y='Max Temp')
plt.title("Wind Speed vs. Latitude for Southern Hemisphere")
plt.grid()
x_values = south_city["Lat"]

y_values = south_city["Wind Speed"]

linreg(south_city["Lat"],south_city["Wind Speed"], "Wind Speed", (-55,30))
# Out:
# The r-squared is: -0.1903157843470486
